# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [30,10]

df_thtd1 = pd.read_csv('thtd1/result_anomaly_score_hum1.csv')
df_thtd2 = pd.read_csv('thtd2/result_anomaly_score_hum1.csv')
df_thtd3 = pd.read_csv('thtd3/result_anomaly_score_hum1.csv')
df_thtd4 = pd.read_csv('thtd4/result_anomaly_score_hum1.csv')
df_thtd5 = pd.read_csv('thtd5/result_anomaly_score_hum1.csv')
df_thtd6 = pd.read_csv('thtd6/result_anomaly_score_hum1.csv')
df_thtd7 = pd.read_csv('thtd7/result_anomaly_score_hum1.csv')
df_thtd8 = pd.read_csv('thtd8/result_anomaly_score_hum1.csv')
df_thtd9 = pd.read_csv('thtd9/result_anomaly_score_hum1.csv')
df_thtd10 = pd.read_csv('thtd10/result_anomaly_score_hum1.csv')
df_thtd11 = pd.read_csv('thtd11/result_anomaly_score_hum1.csv')
df_thtd12 = pd.read_csv('thtd12/result_anomaly_score_hum1.csv')

x = np.arange(64645)
y1 = df_thtd1['score']
y2 = df_thtd2['score']
y3 = df_thtd3['score']
y4 = df_thtd4['score']
y5 = df_thtd5['score']
y6 = df_thtd6['score']
y7 = df_thtd7['score']
y8 = df_thtd8['score']
y9 = df_thtd9['score']
y10 = df_thtd10['score']
y11 = df_thtd11['score']
y12 = df_thtd12['score']

#df_thresh= df_thresh.add(-0.05)
fig, ax = plt.subplots()
#ax.set_ylim(-0.2,0.3)
#ax.axhline(y=0.01, color='red')
ax.set_title('Humidity anomaly score for different minimum contamination', fontweight ="bold")
ax.set_xlabel('Data point (represent of sensor data every 1 minute)')
ax.set_ylabel('Anomaly score (smaller means more likely to be anomaly)')

c1 = ax.plot(y1)
c2 = ax.plot(y2)
c3 = ax.plot(y3)
c4 = ax.plot(y4)
c5 = ax.plot(y5)
c6 = ax.plot(y6)
c7 = ax.plot(y7)
c8 = ax.plot(y8)
c9 = ax.plot(y9)
c10 = ax.plot(y10)
c11 = ax.plot(y11)
c12 = ax.plot(y12)

ax.legend([c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12], labels=['0.1%','0.15%','0.2%','0.25%','0.3%','0.35%','0.4%','0.5%','0.6%','0.7%','0.8%','0.9%' ])
# Out:
# C:\Users\Radityo Fajar\AppData\Local\Temp\ipykernel_6664\856478607.py:54: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend([c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12], labels=['0.1%','0.15%','0.2%','0.25%','0.3%','0.35%','0.4%','0.5%','0.6%','0.7%','0.8%','0.9%' ])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [30,10]

df_thtd1 = pd.read_csv('thtd1/result_anomaly_score_hum1.csv')
df_thtd2 = pd.read_csv('thtd2/result_anomaly_score_hum1.csv')
df_thtd3 = pd.read_csv('thtd3/result_anomaly_score_hum1.csv')
df_thtd4 = pd.read_csv('thtd4/result_anomaly_score_hum1.csv')
df_thtd5 = pd.read_csv('thtd5/result_anomaly_score_hum1.csv')
df_thtd6 = pd.read_csv('thtd6/result_anomaly_score_hum1.csv')
df_thtd7 = pd.read_csv('thtd7/result_anomaly_score_hum1.csv')
df_thtd8 = pd.read_csv('thtd8/result_anomaly_score_hum1.csv')
df_thtd9 = pd.read_csv('thtd9/result_anomaly_score_hum1.csv')
df_thtd10 = pd.read_csv('thtd10/result_anomaly_score_hum1.csv')
df_thtd11 = pd.read_csv('thtd11/result_anomaly_score_hum1.csv')
df_thtd12 = pd.read_csv('thtd12/result_anomaly_score_hum1.csv')

x = np.arange(64645)
y1 = df_thtd1['score'][18000:20000]
y2 = df_thtd2['score'][18000:20000]
y3 = df_thtd3['score'][18000:20000]
y4 = df_thtd4['score'][18000:20000]
y5 = df_thtd5['score'][18000:20000]
y6 = df_thtd6['score'][18000:20000]
y7 = df_thtd7['score'][18000:20000]
y8 = df_thtd8['score'][18000:20000]
y9 = df_thtd9['score'][18000:20000]
y10 = df_thtd10['score'][18000:20000]
y11 = df_thtd11['score'][18000:20000]
y12 = df_thtd12['score'][18000:20000]

#df_thresh= df_thresh.add(-0.05)
fig, ax = plt.subplots()
#ax.set_ylim(-0.2,0.3)
#ax.axhline(y=0.01, color='red')
ax.set_title('Humidity anomaly score for different minimum contamination', fontweight ="bold")
ax.set_xlabel('Data point (represent of sensor data every 1 minute)')
ax.set_ylabel('Anomaly score (smaller means more likely to be anomaly)')

c1 = ax.plot(y1)
c2 = ax.plot(y2)
c3 = ax.plot(y3)
c4 = ax.plot(y4)
c5 = ax.plot(y5)
c6 = ax.plot(y6)
c7 = ax.plot(y7)
c8 = ax.plot(y8)
c9 = ax.plot(y9)
c10 = ax.plot(y10)
c11 = ax.plot(y11)
c12 = ax.plot(y12)

ax.legend([c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12], labels=['0.1%','0.15%','0.2%','0.25%','0.3%','0.35%','0.4%','0.5%','0.6%','0.7%','0.8%','0.9%' ])
# Out:
# C:\Users\Radityo Fajar\AppData\Local\Temp\ipykernel_6664\688263123.py:54: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend([c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12], labels=['0.1%','0.15%','0.2%','0.25%','0.3%','0.35%','0.4%','0.5%','0.6%','0.7%','0.8%','0.9%' ])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [30,10]

df_thtd1 = pd.read_csv('thtd1/result_anomaly_threshold_hum1.csv')
df_thtd2 = pd.read_csv('thtd2/result_anomaly_threshold_hum1.csv')
df_thtd3 = pd.read_csv('thtd3/result_anomaly_threshold_hum1.csv')
df_thtd4 = pd.read_csv('thtd4/result_anomaly_threshold_hum1.csv')
df_thtd5 = pd.read_csv('thtd5/result_anomaly_threshold_hum1.csv')
df_thtd6 = pd.read_csv('thtd6/result_anomaly_threshold_hum1.csv')
df_thtd7 = pd.read_csv('thtd7/result_anomaly_threshold_hum1.csv')
df_thtd8 = pd.read_csv('thtd8/result_anomaly_threshold_hum1.csv')
df_thtd9 = pd.read_csv('thtd9/result_anomaly_threshold_hum1.csv')
df_thtd10 = pd.read_csv('thtd10/result_anomaly_threshold_hum1.csv')
df_thtd11 = pd.read_csv('thtd11/result_anomaly_threshold_hum1.csv')
df_thtd12 = pd.read_csv('thtd12/result_anomaly_threshold_hum1.csv')

x = np.arange(64645)
y1 = df_thtd1['threshold']
y2 = df_thtd2['threshold']
y3 = df_thtd3['threshold']
y4 = df_thtd4['threshold']
y5 = df_thtd5['threshold']
y6 = df_thtd6['threshold']
y7 = df_thtd7['threshold']
y8 = df_thtd8['threshold']
y9 = df_thtd9['threshold']
y10 = df_thtd10['threshold']
y11 = df_thtd11['threshold']
y12 = df_thtd12['threshold']

#df_thresh= df_thresh.add(-0.05)
fig, ax = plt.subplots()
#ax.set_ylim(-0.2,0.3)
#ax.axhline(y=0.01, color='red')
ax.set_title('Humidity anomaly threshold for different minimum contamination', fontweight ="bold")
ax.set_xlabel('Data point (represent of sensor data every 1 minute)')
ax.set_ylabel('Anomaly threshold (smaller means more likely to be anomaly)')

c1 = ax.plot(y1)
c2 = ax.plot(y2)
c3 = ax.plot(y3)
c4 = ax.plot(y4)
c5 = ax.plot(y5)
c6 = ax.plot(y6)
c7 = ax.plot(y7)
c8 = ax.plot(y8)
c9 = ax.plot(y5)
c10 = ax.plot(y6)
c11 = ax.plot(y7)
c12 = ax.plot(y8)

ax.legend([c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12], labels=['0.1%','0.15%','0.2%','0.25%','0.3%','0.35%','0.4%','0.5%','0.6%','0.7%','0.8%','0.9%' ])
# Out:
# C:\Users\Radityo Fajar\AppData\Local\Temp\ipykernel_6664\1912212146.py:54: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend([c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12], labels=['0.1%','0.15%','0.2%','0.25%','0.3%','0.35%','0.4%','0.5%','0.6%','0.7%','0.8%','0.9%' ])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [30,10]

df_thtd1 = pd.read_csv('thtd1/result_anomaly_threshold_hum1.csv')
df_thtd2 = pd.read_csv('thtd2/result_anomaly_threshold_hum1.csv')
df_thtd3 = pd.read_csv('thtd3/result_anomaly_threshold_hum1.csv')
df_thtd4 = pd.read_csv('thtd4/result_anomaly_threshold_hum1.csv')
df_thtd5 = pd.read_csv('thtd5/result_anomaly_threshold_hum1.csv')
df_thtd6 = pd.read_csv('thtd6/result_anomaly_threshold_hum1.csv')
df_thtd7 = pd.read_csv('thtd7/result_anomaly_threshold_hum1.csv')
df_thtd8 = pd.read_csv('thtd8/result_anomaly_threshold_hum1.csv')
df_thtd9 = pd.read_csv('thtd9/result_anomaly_threshold_hum1.csv')
df_thtd10 = pd.read_csv('thtd10/result_anomaly_threshold_hum1.csv')
df_thtd11 = pd.read_csv('thtd11/result_anomaly_threshold_hum1.csv')
df_thtd12 = pd.read_csv('thtd12/result_anomaly_threshold_hum1.csv')

x = np.arange(64645)
y1 = df_thtd1['threshold'][18000:20000]
y2 = df_thtd2['threshold'][18000:20000]
y3 = df_thtd3['threshold'][18000:20000]
y4 = df_thtd4['threshold'][18000:20000]
y5 = df_thtd5['threshold'][18000:20000]
y6 = df_thtd6['threshold'][18000:20000]
y7 = df_thtd7['threshold'][18000:20000]
y8 = df_thtd8['threshold'][18000:20000]
y9 = df_thtd9['threshold'][18000:20000]
y10 = df_thtd10['threshold'][18000:20000]
y11 = df_thtd11['threshold'][18000:20000]
y12 = df_thtd12['threshold'][18000:20000]

#df_thresh= df_thresh.add(-0.05)
fig, ax = plt.subplots()
#ax.set_ylim(-0.2,0.3)
#ax.axhline(y=0.01, color='red')
ax.set_title('Humidity anomaly threshold for different minimum contamination', fontweight ="bold")
ax.set_xlabel('Data point (represent of sensor data every 1 minute)')
ax.set_ylabel('Anomaly threshold (smaller means more likely to be anomaly)')

c1 = ax.plot(y1)
c2 = ax.plot(y2)
c3 = ax.plot(y3)
c4 = ax.plot(y4)
c5 = ax.plot(y5)
c6 = ax.plot(y6)
c7 = ax.plot(y7)
c8 = ax.plot(y8)
c9 = ax.plot(y9)
c10 = ax.plot(y10)
c11 = ax.plot(y11)
c12 = ax.plot(y12)

ax.legend([c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12], labels=['0.1%','0.15%','0.2%','0.25%','0.3%','0.35%','0.4%','0.5%','0.6%','0.7%','0.8%','0.9%' ])
# Out:
# C:\Users\Radityo Fajar\AppData\Local\Temp\ipykernel_6664\2571090066.py:54: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend([c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12], labels=['0.1%','0.15%','0.2%','0.25%','0.3%','0.35%','0.4%','0.5%','0.6%','0.7%','0.8%','0.9%' ])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [30,10]

df_thtd1_thresh = pd.read_csv('thtd1/result_anomaly_threshold_hum1.csv')
df_thtd1 = pd.read_csv('thtd1/result_anomaly_score_hum1.csv')
df_thtd12_thresh = pd.read_csv('thtd12/result_anomaly_threshold_hum1.csv')
df_thtd12 = pd.read_csv('thtd12/result_anomaly_score_hum1.csv')
fig, ax = plt.subplots()
x = np.arange(64645)
y1 = df_thtd1_thresh['threshold']
y2 = df_thtd12_thresh['threshold']
y3 = df_thtd1['score']
y4 = df_thtd12['score']

c1 = ax.plot(y1)
c2 = ax.plot(y2)
c3 = ax.plot(y3)
c4 = ax.plot(y4)

ax.set_title('Humidity anomaly threshold for different minimum contamination', fontweight ="bold")
ax.set_xlabel('Data point (represent of sensor data every 1 minute)')
ax.set_ylabel('Anomaly threshold (smaller means more likely to be anomaly)')

ax.legend([c1,c2,c3,c4], labels=['Threshold for 0.1%','Threshold for 0.9%','Score for 0.1%', 'Score for 0.9%'])
# Out:
# C:\Users\Radityo Fajar\AppData\Local\Temp\ipykernel_6664\162808693.py:26: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend([c1,c2,c3,c4], labels=['Threshold for 0.1%','Threshold for 0.9%','Score for 0.1%', 'Score for 0.9%'])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [30,10]

df_thtd1_thresh = pd.read_csv('thtd1/result_anomaly_threshold_hum1.csv')
df_thtd1 = pd.read_csv('thtd1/result_anomaly_score_hum1.csv')
df_thtd12_thresh = pd.read_csv('thtd12/result_anomaly_threshold_hum1.csv')
df_thtd12 = pd.read_csv('thtd12/result_anomaly_score_hum1.csv')
fig, ax = plt.subplots()
x = np.arange(64645)
y1 = df_thtd1_thresh['threshold'][20000:22000]
y2 = df_thtd12_thresh['threshold'][20000:22000]
y3 = df_thtd1['score'][20000:22000]
y4 = df_thtd12['score'][20000:22000]

c1 = ax.plot(y1)
c2 = ax.plot(y2)
c3 = ax.plot(y3)
c4 = ax.plot(y4)

ax.set_title('Humidity anomaly threshold for different minimum contamination (zoom)', fontweight ="bold")
ax.set_xlabel('Data point (represent of sensor data every 1 minute)')
ax.set_ylabel('Anomaly threshold (smaller means more likely to be anomaly)')

ax.legend([c1,c2,c3,c4], labels=['Threshold for 0.1%','Threshold for 0.9%','Score for 0.1%', 'Score for 0.9%'])
# Out:
# C:\Users\Radityo Fajar\AppData\Local\Temp\ipykernel_6664\438896387.py:26: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend([c1,c2,c3,c4], labels=['Threshold for 0.1%','Threshold for 0.9%','Score for 0.1%', 'Score for 0.9%'])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [30,10]

df_thtd1 = pd.read_csv('thtd1/result_anomaly_score_temp1.csv')
df_thtd2 = pd.read_csv('thtd2/result_anomaly_score_temp1.csv')
df_thtd3 = pd.read_csv('thtd3/result_anomaly_score_temp1.csv')
df_thtd4 = pd.read_csv('thtd4/result_anomaly_score_temp1.csv')
df_thtd5 = pd.read_csv('thtd5/result_anomaly_score_temp1.csv')
df_thtd6 = pd.read_csv('thtd6/result_anomaly_score_temp1.csv')
df_thtd7 = pd.read_csv('thtd7/result_anomaly_score_temp1.csv')
df_thtd8 = pd.read_csv('thtd8/result_anomaly_score_temp1.csv')
df_thtd9 = pd.read_csv('thtd9/result_anomaly_score_temp1.csv')
df_thtd10 = pd.read_csv('thtd10/result_anomaly_score_temp1.csv')
df_thtd11 = pd.read_csv('thtd11/result_anomaly_score_temp1.csv')
df_thtd12 = pd.read_csv('thtd12/result_anomaly_score_temp1.csv')

x = np.arange(64645)
y1 = df_thtd1['score']
y2 = df_thtd2['score']
y3 = df_thtd3['score']
y4 = df_thtd4['score']
y5 = df_thtd5['score']
y6 = df_thtd6['score']
y7 = df_thtd7['score']
y8 = df_thtd8['score']
y9 = df_thtd9['score']
y10 = df_thtd10['score']
y11 = df_thtd11['score']
y12 = df_thtd12['score']

#df_thresh= df_thresh.add(-0.05)
fig, ax = plt.subplots()
#ax.set_ylim(-0.2,0.3)
#ax.axhline(y=0.01, color='red')
ax.set_title('Temperature anomaly score for different minimum contamination', fontweight ="bold")
ax.set_xlabel('Data point (represent of sensor data every 1 minute)')
ax.set_ylabel('Anomaly score (smaller means more likely to be anomaly)')

c1 = ax.plot(y1)
c2 = ax.plot(y2)
c3 = ax.plot(y3)
c4 = ax.plot(y4)
c5 = ax.plot(y5)
c6 = ax.plot(y6)
c7 = ax.plot(y7)
c8 = ax.plot(y8)
c9 = ax.plot(y9)
c10 = ax.plot(y10)
c11 = ax.plot(y11)
c12 = ax.plot(y12)

ax.legend([c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12], labels=['0.1%','0.15%','0.2%','0.25%','0.3%','0.35%','0.4%','0.5%','0.6%','0.7%','0.8%','0.9%' ])
# Out:
# C:\Users\Radityo Fajar\AppData\Local\Temp\ipykernel_6664\2078997329.py:54: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend([c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12], labels=['0.1%','0.15%','0.2%','0.25%','0.3%','0.35%','0.4%','0.5%','0.6%','0.7%','0.8%','0.9%' ])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [30,10]

df_thtd1 = pd.read_csv('thtd1/result_anomaly_score_temp1.csv')
df_thtd2 = pd.read_csv('thtd2/result_anomaly_score_temp1.csv')
df_thtd3 = pd.read_csv('thtd3/result_anomaly_score_temp1.csv')
df_thtd4 = pd.read_csv('thtd4/result_anomaly_score_temp1.csv')
df_thtd5 = pd.read_csv('thtd5/result_anomaly_score_temp1.csv')
df_thtd6 = pd.read_csv('thtd6/result_anomaly_score_temp1.csv')
df_thtd7 = pd.read_csv('thtd7/result_anomaly_score_temp1.csv')
df_thtd8 = pd.read_csv('thtd8/result_anomaly_score_temp1.csv')
df_thtd9 = pd.read_csv('thtd9/result_anomaly_score_temp1.csv')
df_thtd10 = pd.read_csv('thtd10/result_anomaly_score_temp1.csv')
df_thtd11 = pd.read_csv('thtd11/result_anomaly_score_temp1.csv')
df_thtd12 = pd.read_csv('thtd12/result_anomaly_score_temp1.csv')

x = np.arange(64645)
y1 = df_thtd1['score'][19400:19800]
y2 = df_thtd2['score'][19400:19800]
y3 = df_thtd3['score'][19400:19800]
y4 = df_thtd4['score'][19400:19800]
y5 = df_thtd5['score'][19400:19800]
y6 = df_thtd6['score'][19400:19800]
y7 = df_thtd7['score'][19400:19800]
y8 = df_thtd8['score'][19400:19800]
y9 = df_thtd9['score'][19400:19800]
y10 = df_thtd10['score'][19400:19800]
y11 = df_thtd11['score'][19400:19800]
y12 = df_thtd12['score'][19400:19800]

#df_thresh= df_thresh.add(-0.05)
fig, ax = plt.subplots()
#ax.set_ylim(-0.2,0.3)
#ax.axhline(y=0.01, color='red')
ax.set_title('Temperature anomaly score for different minimum contamination (zoom)', fontweight ="bold")
ax.set_xlabel('Data point (represent of sensor data every 1 minute)')
ax.set_ylabel('Anomaly score (smaller means more likely to be anomaly)')

c1 = ax.plot(y1)
c2 = ax.plot(y2)
c3 = ax.plot(y3)
c4 = ax.plot(y4)
c5 = ax.plot(y5)
c6 = ax.plot(y6)
c7 = ax.plot(y7)
c8 = ax.plot(y8)
c9 = ax.plot(y9)
c10 = ax.plot(y10)
c11 = ax.plot(y11)
c12 = ax.plot(y12)

ax.legend([c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12], labels=['0.1%','0.15%','0.2%','0.25%','0.3%','0.35%','0.4%','0.5%','0.6%','0.7%','0.8%','0.9%' ])
# Out:
# C:\Users\Radityo Fajar\AppData\Local\Temp\ipykernel_6664\258329729.py:54: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend([c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12], labels=['0.1%','0.15%','0.2%','0.25%','0.3%','0.35%','0.4%','0.5%','0.6%','0.7%','0.8%','0.9%' ])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [30,10]

df_thtd1_thresh = pd.read_csv('thtd1/result_anomaly_threshold_temp1.csv')
df_thtd1 = pd.read_csv('thtd1/result_anomaly_score_temp1.csv')
df_thtd12_thresh = pd.read_csv('thtd12/result_anomaly_threshold_temp1.csv')
df_thtd12 = pd.read_csv('thtd12/result_anomaly_score_temp1.csv')
fig, ax = plt.subplots()
x = np.arange(64645)
y1 = df_thtd1_thresh['threshold']
y2 = df_thtd12_thresh['threshold']
y3 = df_thtd1['score']
y4 = df_thtd12['score']

c1 = ax.plot(y1)
c2 = ax.plot(y2)
c3 = ax.plot(y3)
c4 = ax.plot(y4)

ax.set_title('Temperature anomaly threshold for different minimum contamination', fontweight ="bold")
ax.set_xlabel('Data point (represent of sensor data every 1 minute)')
ax.set_ylabel('Anomaly threshold (smaller means more likely to be anomaly)')

ax.legend([c1,c2,c3,c4], labels=['Threshold for 0.1%','Threshold for 0.9%','Score for 0.1%', 'Score for 0.9%'])
# Out:
# C:\Users\Radityo Fajar\AppData\Local\Temp\ipykernel_6664\4162030542.py:26: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend([c1,c2,c3,c4], labels=['Threshold for 0.1%','Threshold for 0.9%','Score for 0.1%', 'Score for 0.9%'])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [30,10]

df_thtd1_thresh = pd.read_csv('thtd1/result_anomaly_threshold_temp1.csv')
df_thtd1 = pd.read_csv('thtd1/result_anomaly_score_temp1.csv')
df_thtd12_thresh = pd.read_csv('thtd12/result_anomaly_threshold_temp1.csv')
df_thtd12 = pd.read_csv('thtd12/result_anomaly_score_temp1.csv')
fig, ax = plt.subplots()
x = np.arange(64645)
y1 = df_thtd1_thresh['threshold'][19400:19800]
y2 = df_thtd12_thresh['threshold'][19400:19800]
y3 = df_thtd1['score'][19400:19800]
y4 = df_thtd12['score'][19400:19800]

c1 = ax.plot(y1)
c2 = ax.plot(y2)
c3 = ax.plot(y3)
c4 = ax.plot(y4)

ax.set_title('Temperature anomaly threshold for different minimum contamination (zoom)', fontweight ="bold")
ax.set_xlabel('Data point (represent of sensor data every 1 minute)')
ax.set_ylabel('Anomaly threshold (smaller means more likely to be anomaly)')

ax.legend([c1,c2,c3,c4], labels=['Threshold for 0.1%','Threshold for 0.9%','Score for 0.1%', 'Score for 0.9%'])
# Out:
# C:\Users\Radityo Fajar\AppData\Local\Temp\ipykernel_6664\2678517836.py:26: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend([c1,c2,c3,c4], labels=['Threshold for 0.1%','Threshold for 0.9%','Score for 0.1%', 'Score for 0.9%'])
